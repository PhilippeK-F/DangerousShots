# %% [markdown]
# # 01 — Exploration des données
#
# TODO: décrire la source et l'objectif de l'analyse

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.loaders import load_csv, load_api, load_sql
from src.analysis import clean, summary_stats

# %% [markdown]
# ## 1. Chargement
#
# TODO: choisir et décommenter la source adaptée

# %%
# --- CSV local ---
# df = load_csv('../data/raw/ton_fichier.csv', sep=';', parse_dates=['date'])

# --- API REST ---
# df = load_api()

# --- Base SQL ---
# df = load_sql('SELECT * FROM ta_table LIMIT 1000')

# Placeholder
df = pd.DataFrame({'date': pd.date_range('2024-01-01', periods=5), 'valeur': [10, 20, 15, 30, 25]})
df.head()

# %% [markdown]
# ## 2. Aperçu brut

# %%
print(f'Dimensions : {df.shape}')
print(f'\nTypes :')
print(df.dtypes)
print(f'\nValeurs manquantes :')
print(df.isnull().sum())

# %% [markdown]
# ## 3. Nettoyage

# %%
df_clean = clean(df)
print(summary_stats(df_clean))

# %% [markdown]
# ## 4. Visualisations exploratoires
#
# TODO: ajouter tes graphiques d'exploration

# %%
# TODO: adapter les colonnes
# from src.analysis import plot_distribution, plot_timeseries, plot_correlation
# plot_distribution(df_clean, 'valeur')
# plot_timeseries(df_clean, 'date', 'valeur')
# plot_correlation(df_clean)
# plt.show()

# %% [markdown]
# ## 5. Observations
#
# TODO: noter ici les observations clés de l'exploration
# -
# -
# -
