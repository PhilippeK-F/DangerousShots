# %% [markdown]
# # 02 — Analyse et KPIs
#
# TODO: décrire les questions auxquelles cette analyse répond

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import matplotlib.pyplot as plt

from src.loaders import load_csv
from src.analysis import clean, aggregate, compute_kpis, plot_bar, plot_timeseries

# %% [markdown]
# ## 1. Chargement des données nettoyées
#
# TODO: charger depuis data/processed/ si tu as sauvegardé le résultat du notebook 01

# %%
# TODO: remplacer par tes données réelles
# df = pd.read_csv('../data/processed/cleaned.csv', parse_dates=['date'])

# Placeholder
df = pd.DataFrame({'date': pd.date_range('2024-01-01', periods=5), 'categorie': ['A','B','A','B','A'], 'valeur': [10, 20, 15, 30, 25]})
df.head()

# %% [markdown]
# ## 2. KPIs

# %%
kpis = compute_kpis(df)
for k, v in kpis.items():
    print(f'{k}: {v}')

# %% [markdown]
# ## 3. Agrégations
#
# TODO: adapter aggregate() dans src/analysis/analyze.py à tes besoins

# %%
df_agg = aggregate(df)
df_agg

# %% [markdown]
# ## 4. Visualisations
#
# TODO: adapter les colonnes

# %%
# TODO: décommenter et adapter
# plot_bar(df.groupby('categorie')['valeur'].sum().reset_index(), 'categorie', 'valeur', 'Valeur par catégorie')
# plot_timeseries(df, 'date', 'valeur', 'Évolution dans le temps')
# plt.show()

# %% [markdown]
# ## 5. Export des résultats
#
# TODO: sauvegarder les résultats pour le dashboard

# %%
# TODO: sauvegarder le DataFrame nettoyé / agrégé
# df.to_csv('../data/processed/cleaned.csv', index=False)
# df_agg.to_csv('../data/processed/aggregated.csv', index=False)

# %% [markdown]
# ## 6. Conclusions
#
# TODO: synthèse des résultats
# -
# -
# -
